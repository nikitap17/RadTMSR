# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import data
dfTot = pd.read_excel("asreview_dataset_relevant_Radicalization.xlsx")
dfTot.head()
# Out:
#    record_id  Unnamed: 0 Publication Type  \
# 0      50129       65738                J
# 1       2624        5295                J
# 2      35510       44004                J
# 3      43427       55121                J
# 4        986        1384                J
#
#                                              Authors Book Authors  \
# 0  Bélanger, JJ; Adam-Troian, J; Nisa, CF; Schump...          NaN
# 1                               Beller, J; Kröger, C          NaN
# 2                    Decety, J; Pape, R; Workman, CI          NaN
# 3              Doosje, B; Loseman, A; van den Bos, K          NaN
# 4            Echelmeyer, L; Slotboom, AM; Weerman, F          NaN
#
#   Book Editors Book Group Authors  \
# 0          NaN                NaN
# 1          NaN                NaN
# 2          NaN                NaN
# 3          NaN                NaN
# 4          NaN                NaN
#
#                                    Author Full Names Book Author Full Names  \
# 0  Belanger, Jocelyn J.; Adam-Troian, Jais; Nisa,...                    NaN
# 1                Beller, Johannes; Kroger, Christoph                    NaN
# 2   Decety, Jean; Pape, Robert; Workman, Clifford I.                    NaN
# 3  Doosje, Bertjan; Loseman, Annemarie; van den B...                    NaN
# 4  Echelmeyer, Lea; Slotboom, Anne-Marie; Weerman...                    NaN
#
#    Group Authors  ...   Pubmed Id Open Access Designations  \
# 0            NaN  ...  35678112.0           Green Accepted
# 1            NaN  ...         NaN                      NaN
# 2            NaN  ...  29091541.0          Green Published
# 3            NaN  ...         NaN                      NaN
# 4            NaN  ...         NaN                   hybrid
#
#   Highly Cited Status  Hot Paper Status Date of Export   UT (Unique WOS ID)  \
# 0                 NaN               NaN     2023-11-18  WOS:000807979500001
# 1                 NaN               NaN     2023-11-18  WOS:000449503300005
# 2                 NaN               NaN     2023-11-18  WOS:000452190600001
# 3                 NaN               NaN     2023-11-18  WOS:000324059700010
# 4                 NaN               NaN     2023-11-18  WOS:001052712400001
#
#   Web of Science Record exported_notes_1 included asreview_ranking
# 0                     0              NaN        1                1
# 1                     0              NaN        1                2
# 2                     0              NaN        1                3
# 3                     0              NaN        1                4
# 4                     0              NaN        1                5
#
# [5 rows x 77 columns]

# %% [markdown]
# ## Data overview

# %%
# Data overview
print('Number of articles: {}'.format(len(dfTot)))
# Out:
# Number of articles: 4019

# %%
dfTot["Title"] = dfTot["Title"].apply(lambda x: str(x).lower())

# %%
dfTot['Publication Type'].value_counts()
# Out:
# Publication Type
# J    3742
# C     233
# S      28
# B      16
# Name: count, dtype: int64

# %%
print(dfTot['Publication Year'].min())
print(dfTot['Publication Year'].max())
dfTot['Publication Year'].sort_values().hist()
# Out:
# 1991
# 2023
# <Axes: >

# %%
# Number of Journals
len(dfTot['Journal ISO Abbreviation'].unique())
# Out:
# 1114

# %%
# Author ditribution
clean_authors = dfTot['Authors'].apply(lambda x: re.sub(r'[^\w;]', '', x))

[(a.split(";")) for a in clean_authors]

author_names = []
for a in clean_authors:
  names = a.split(";")
  for name in names:
    author_names.append(name)

authors = pd.DataFrame(pd.Series(author_names).value_counts())
authors
# Out:
#                count
# GillP             34
# KruglanskiAW      24
# FreilichJD        23
# ChermakSM         22
# RousseauC         20
# ...              ...
# DochartaighNO      1
# MagniG             1
# SgroPM             1
# BhattacharyaS      1
# ThorntonJ          1
#
# [6272 rows x 1 columns]

# %%
authors.to_excel("authors.xlsx")

# %%
#print(len(dfTot))
#dfTot = dfTot[dfTot[["Title", "DOI", "record_id"]].isnull() | ~dfTot[dfTot[["Title", "DOI", "record_id"]].notnull()].duplicated(subset=["Title", "DOI", "record_id"],keep='first')]
#len(dfTot)

# %%
data = dfTot[["record_id","Author Keywords"]].copy()
data.rename(columns={'Author Keywords': 'keywords'}, inplace=True)

# %%
data = data.dropna(subset = ['keywords'])

# %% [markdown]
# # Preprocessing
#
# **Pipeline**:
#
# `data` --> `cleaning` --> `exclusion filter (stopwords, countries, exclusion terms)` --> `classification and replacement` --> `clean_data` --> `nounbydoc` --> *transfer to R* --> `negative binomial` --> `topic modelling` --> `frequence analysis` --> `co-occurrence analysis` --> *transfer to Python* --> `co-occurrence network map`

# %% [markdown]
# ### 1. Cleaning

# %%
# Exclude NaNs
data = data.dropna(subset = ['keywords'])

# lower case, replace "-" with space, and split keywords
data.keywords = data.keywords.apply(lambda x: x.replace("-"," ").split("; "))
data.keywords = data.keywords.apply(lambda x: [str(item).lower() for item in x])
data
# Out:
#       record_id                                           keywords
# 0         50129  [goal shielding, passion, radicalization, sign...
# 1          2624  [suicide attacks, extremism, radicalization, r...
# 2         35510  [social neuroscience, political neuroscience, ...
# 5           728  [uncertainty identity theory, social identity,...
# 7         43755  [ideological extremism, homegrown terrorism, l...
# ...         ...                                                ...
# 4012      18353  [institutional logics, microfoundations, polit...
# 4013       2048  [power, islam, muslim clergy, prevention, radi...
# 4014      24073  [right wing extremism, fascism, women, golden ...
# 4016      50382  [goal, goal setting, goal formation, personali...
# 4017       2188  [pai subject, pai teaching materials, religiou...
#
# [3093 rows x 2 columns]

# %%
('Number of keywords: {}'.format(np.array([len(d) for d in data.keywords]).sum()))
# Out:
# 'Number of keywords: 16751'

# %% [markdown]
# ### 2. Exclusion filter (stopwords, countries, and exclusion terms)

# %%
from stop_words import get_stop_words
stoplist = get_stop_words('en')

from country_list import countries_for_language
countries_dict = dict(countries_for_language('en'))
countries_raw = list(countries_dict.values())
countries = [term.lower() for term in countries_raw]

# %%
exclusion_list = pd.read_excel("Exclusion_def.xlsx")
excl_list = list(exclusion_list.Exclusion)
excl_list = [str(item) for item in excl_list]
region_list = ['africa','asia','europe','america','middle east',
               "western europe", "northern ireland", "hong kong", "basque country",
               "eastern europe", "southeast asia", "south asia", "somali", "britain", "latin america", "central asia",
               "palestine", 'middle east and north africa']

# %%
exclusion_filter = set(excl_list + countries + stoplist + region_list)

# %% [markdown]
# *Apply exclusion filter*

# %%
data.keywords = data.keywords.apply(lambda x: [item for item in x if item not in exclusion_filter])
data
# Out:
#       record_id                                           keywords
# 0         50129  [goal shielding, passion, radicalization, sign...
# 1          2624  [suicide attacks, extremism, radicalization, r...
# 2         35510  [social neuroscience, political neuroscience, ...
# 5           728  [uncertainty identity theory, social identity,...
# 7         43755  [ideological extremism, homegrown terrorism, l...
# ...         ...                                                ...
# 4012      18353  [institutional logics, microfoundations, polit...
# 4013       2048  [power, islam, muslim clergy, radical islam ex...
# 4014      24073  [right wing extremism, fascism, women, golden ...
# 4016      50382  [goal setting, goal formation, personality, so...
# 4017       2188  [pai teaching materials, religious tolerance, ...
#
# [3093 rows x 2 columns]

# %% [markdown]
# ### 3. Term Classification and Replacement (TMSR dictionary.py)

# %%
from TMSR_dictionary_finall import word_dict
from Word_functions.word_functions_py import classification, extend_keywords, to_nounbydoc

# %%
keywords_list = sum(data.keywords, [])

# %%
count_dict, uniques, terms_in_cat_dict = classification(keywords_list,word_dict)

# %%
sorted(count_dict.items(), key=lambda item: item[1], reverse = True)
# Out:
# [('radicalism', 3606),
#  ('far right', 712),
#  ('islamist', 523),
#  ('conflict', 307),
#  ('adolescence', 273),
#  ('religiosity', 273),
#  ('identity', 257),
#  ('populism', 249),
#  ('internet', 228),
#  ('ideology', 202),
#  ('elections', 200),
#  ('immigration', 199),
#  ('sex', 194),
#  ('norms', 181),
#  ('violence', 180),
#  ('social media', 146),
#  ('politics', 140),
#  ('culture', 140),
#  ('education', 138),
#  ('nationalism', 134),
#  ('criminality', 131),
#  ('economy', 127),
#  ('justice', 126),
#  ('emotion', 125),
#  ('security', 107),
#  ('mental health', 106),
#  ('mobilization', 104),
#  ('threat', 104),
#  ('democracy', 104),
#  ('deprivation', 96),
#  ('cognition', 92),
#  ('activism', 87),
#  ('polarization', 87),
#  ('deradicalization', 83),
#  ('social exclusion', 77),
#  ('lone actor', 72),
#  ('morality', 68),
#  ('far left', 62),
#  ('prejudice', 60),
#  ('misogyny', 58),
#  ('crisis', 58),
#  ('social support', 58),
#  ('aggression', 57),
#  ('fundamentalism', 56),
#  ('hate', 55),
#  ('islamophobia', 52),
#  ('foreign fighter', 51),
#  ('significance quest', 50),
#  ('authoritarianism', 48),
#  ('discrimination', 48),
#  ('discourse', 46),
#  ('status', 45),
#  ('masculinity', 45),
#  ('conspiracy', 45),
#  ('employment', 44),
#  ('propaganda', 43),
#  ('satisfaction', 41),
#  ('state', 41),
#  ('community', 41),
#  ('family', 40),
#  ('diversity', 36),
#  ('group process', 36),
#  ('racism', 35),
#  ('superiority', 35),
#  ('environmentalism', 34),
#  ('rationality', 34),
#  ('social change', 33),
#  ('trust', 31),
#  ('uncertainty', 31),
#  ('integration', 31),
#  ('ptsd', 30),
#  ('peace', 30),
#  ('white race', 29),
#  ('sacred values', 29),
#  ('language', 29),
#  ('minority', 29),
#  ('intolerance', 28),
#  ('resilience', 28),
#  ('martyrdom', 27),
#  ('poverty', 27),
#  ('globalization', 26),
#  ('urban', 25),
#  ('personality', 25),
#  ('political engagement', 24),
#  ('fusion', 23),
#  ('climate change', 23),
#  ('competition', 23),
#  ('segregation', 21),
#  ('skepticism', 20),
#  ('stress', 20),
#  ('misinformation', 20),
#  ('deviance', 18),
#  ('mortality salience', 18),
#  ('anger', 18),
#  ('intergroup contact', 17),
#  ('fear', 16),
#  ('neural', 16),
#  ('conservatism', 15),
#  ('suicide', 15),
#  ('elites', 15),
#  ('self control', 14),
#  ('system justification', 14),
#  ('dehumanization', 14),
#  ('liberalism', 13),
#  ('altruism', 13),
#  ('narcissism', 13),
#  ('empathy', 12),
#  ('anxiety', 12),
#  ('conformity', 11),
#  ('dogmatism', 11),
#  ('autism', 11),
#  ('dark triad', 11),
#  ('social coherence', 11),
#  ('honor', 10),
#  ('anomia', 9),
#  ('patriotism', 9),
#  ('depression', 9),
#  ('wellbeing', 9),
#  ('teachers', 9),
#  ('nostalgia', 8),
#  ('autonomy', 8),
#  ('political agency', 8),
#  ('victimization', 7),
#  ('apocalypticism', 6),
#  ('schizophrenia', 6),
#  ('school', 6),
#  ('consensus', 6),
#  ('neighborhood', 6),
#  ('abuse', 6),
#  ('iq', 5),
#  ('violence exposure', 5),
#  ('risk taking', 4),
#  ('capitalism', 4),
#  ('law abidance', 3),
#  ('cynicism', 3),
#  ('genes', 3),
#  ('sports', 3),
#  ('peers', 3),
#  ('animal rights', 2),
#  ('pessimism', 2),
#  ('hope', 2),
#  ('borderline', 2),
#  ('social skills', 1),
#  ('self harm', 1),
#  ('substance use', 1),
#  ('therapy', 1),
#  ('health', 1),
#  ('neurotransmitter', 1),
#  ('age', 0),
#  ('digital literacy', 0),
#  ('adhd', 0)]

# %%
print(f"{len(uniques)} not classified keywords, with {len(set(uniques))} unique terms.")
# Out:
# 3597 not classified keywords, with 2660 unique terms.

# %%
from collections import Counter
 
frequency = Counter(uniques)
print(frequency)
# Out:
# Counter({'text networks': 1, 'abnormality': 1, 'radio': 1, 'political opportunities': 1, 'feminism': 1, 'idealist hearths': 1, 'social interactions': 1, 'platforms': 1, 'professional': 1, 'false self': 1, 'involvement vs. events': 1, 'rebel recruitment': 1, 'link recommendation': 1, 'certainty': 1, 'sovereignty': 1, 'primordialists': 1, 'accommodation': 1, 'vividness': 1, 'ethnologue': 1, 'conversion': 1, 'multiple imputation by chained equations': 1, 'dhkp/c': 1, 'transnational issue agendas': 1, 'sociology': 1, 'issue trade offs': 1, 'state dependent priorities': 1, 'political consumerism': 1, 'extrajudicial killings': 1, 'school shooters': 1, 'open source intelligence': 1, 'turkish fighters': 1, 'political regime': 1, 'de demonisation': 1, 'school collaboration': 1, 'network formation': 1, 'rejection of islam': 1, 'objectalisation': 1, 'perceived western influence': 1, 'kosovo': 1, 'secession': 1, 'regional variation': 1, 'autobiographies': 1, 'international recognition': 1, 'disaggregation': 1, "shi'a muslim": 1, 'perception gap': 1, 'loss of reality': 1, 'sectarian disturbances': 1, 'pragmatics': 1, 'political protection': 1, 'lgtbq+': 1, 'social representations': 1, 'human needs': 1, 'counterinsurgency': 1, 'psychological vulnerabilities': 1, 'demographics': 1, 'methodological perspectives': 1, 'non violence': 1, 'american muslims': 1, 'non violent pathways': 1, 'digital society': 1, 'storytelling': 1, 'temporal associations': 1, 'sweden democrats': 1, 'psychotype': 1, 'hacking': 1, 'publicity': 1, 'guerrilla': 1, 'bosnia and herzegovina (b': 1, 'salience': 1, 'tools for influencing': 1, 'brenton tarrant (1990 )': 1, 'sikh': 1, 'peril': 1, 'excessive police action': 1, 'foucault': 1, 'rejection sensitivity': 1, 'holistic knowing': 1, 'madaris': 1, 'crimes': 1, 'east central europe': 1, 'feminist perspectives on violence': 1, 'mobilities': 1, 'ancient religions': 1, '9/11': 1, 'modeling and simulation': 1, 'loss of being': 1, 'need for relatedness': 1, 'mena region': 1, 'sharia4belgium': 1, 'local actors': 1, 'moderate islam': 1, 'bohemian index': 1, 'madrassa': 1, 'egalisation': 1, 'backlash': 1, 'attitudes towards violence': 1, 'social contract': 1, 'tracking': 1, 'humility': 1, 'guerrilla violence': 1, 'east timor': 1, 'doppelganger': 1, 'national attitudes': 1, 'banalisation': 1, 'mind invasion': 1, 'intergroup behavior': 1, 'religious terrrism': 1, 'structural root causes': 1, 'manipulation': 1, 'virtual reality': 1, 'religion and state': 1, 'historical interpretation': 1, 'familialism and de familialism': 1, 'muslim world': 1, 'text mining': 1, 'dynamical systems theory': 1, 'evolution games': 1, 'visual methods': 1, 'agent based models': 1, 'ethnic reconciliation': 1, 'healing': 1, 'boldness': 1, 'o40': 1, 'complex systems': 1, 'rights': 1, 'natural resources': 1, "'othering'": 1, 'united nations alliance of civilisations': 1, 'volatility': 1, 'intelligent tutoring system': 1, 'animism': 1, 'empirical analyses': 1, 'institutional non state organisations': 1, 'text analytics': 1, 'trade networks': 1, 'reputation': 1, 'domestic violence': 1, 'd': 1, 'dark participation': 1, 'dynamic secularism': 1, 'flocking and feathering': 1, 'analytic hierarchy process': 1, 'encadrement': 1, "people's party our slovakia": 1, 'drought': 1, 'institutions': 1, 'insight problems': 1, 'incelexit': 1, 'rwandan genocide': 1, 'sentiments': 1, 'mentorship': 1, 'south eastern europe': 1, 'top income percentile shares': 1, 'anticipation': 1, 'home rule': 1, 'triggers': 1, 'bas': 1, 'authenticity': 1, 'critical realism': 1, 'biblicism': 1, 'quer denken': 1, 'civil society organizations': 1, 'oil': 1, 'j15': 1, 'deportation': 1, 'psychiatrization': 1, 'philosophy of technology': 1, 'social structure social learning': 1, 'mass shooting': 1, 'extreme bounds analysis': 1, 'villain': 1, 'symbiosis': 1, 'parades': 1, 'perpetrator': 1, 'violence against other people': 1, 'psychiatric evidence': 1, 'semantic annotation': 1, 'geography': 1, 'inoculati ...

# %% [markdown]
# **van Lissa in word_functions.R:**
#
# "The order of the dictionary matters: Words are replaced by the first match in
# the dictionary. So more important categories should be listed first."
#
# Apperently, van Lissa has got some overlapping categories as well.
#
# How do we want to deal with the category issue? If we want to prune the words, we need to replace the original words with the overarching category before the negative binomial. However, we will lose the possibility to classify words into multiple categories and would have to make an artificial "clear cut" between categories.
#
# Alternatively, we could impute additional keywords: imagine one keyword is "left-wing radicalism", then this word would fall into the categories, let's say, "radicalism" and "far_left". In this case, the keyword "left-wing radicalism" would be replaced by both categories "radicalism" and "far_left". I think this might be a good solution, since we would lose a lot of information otherwise.
#
# For abstracts, I would deal differently with the replacement: sort the dictionary from most specific (e.g. far-right) to most generic (e.g. readicalism) and replace by the first occurrence.

# %%
play_df = data.loc[0:5].copy(deep = True)
play_df["cat_keywords"] = play_df.keywords.apply(lambda x: extend_keywords(x,word_dict))
play_df
# Out:
#    record_id                                           keywords  \
# 0      50129  [goal shielding, passion, radicalization, sign...
# 1       2624  [suicide attacks, extremism, radicalization, r...
# 2      35510  [social neuroscience, political neuroscience, ...
# 5        728  [uncertainty identity theory, social identity,...
#
#                                         cat_keywords
# 0  [goal shielding, radicalism, sacred values, si...
# 1                       [fundamentalism, radicalism]
# 2  [social neuroscience, group process, microsoci...
# 5  [populism, identity, autocratic leadership, ra...

# %%
clean_data = data.copy(deep = True)
clean_data["cat_keywords"] = clean_data.keywords.apply(lambda x: extend_keywords(x,word_dict))
clean_data
# Out:
#       record_id                                           keywords  \
# 0         50129  [goal shielding, passion, radicalization, sign...
# 1          2624  [suicide attacks, extremism, radicalization, r...
# 2         35510  [social neuroscience, political neuroscience, ...
# 5           728  [uncertainty identity theory, social identity,...
# 7         43755  [ideological extremism, homegrown terrorism, l...
# ...         ...                                                ...
# 4012      18353  [institutional logics, microfoundations, polit...
# 4013       2048  [power, islam, muslim clergy, radical islam ex...
# 4014      24073  [right wing extremism, fascism, women, golden ...
# 4016      50382  [goal setting, goal formation, personality, so...
# 4017       2188  [pai teaching materials, religious tolerance, ...
#
#                                            cat_keywords
# 0     [radicalism, significance quest, goal shieldin...
# 1                          [radicalism, fundamentalism]
# 2     [radicalism, political neuroscience, social ne...
# 5     [radicalism, populism, uncertainty, identity, ...
# 7     [radicalism, significance quest, violence, ide...
# ...                                                 ...
# 4012  [institutional logics, microfoundations, cultu...
# 4013  [religiosity, superiority, radicalism, muslim ...
# 4014  [radicalism, far right, nationalism, habitus, ...
# 4016  [goal setting, goal formation, social attitude...
# 4017  [intolerance, pai teaching materials, school, ...
#
# [3093 rows x 3 columns]

# %%
#df_test = clean_data.copy(deep = True).reset_index()

# %%
print(list(set(clean_data.keywords[21])))
print(list(clean_data.cat_keywords[21]))
# Out:
# ['populist radical right', 'optimal distinctiveness', 'social identities', 'semi structured interviews']
# ['radicalism', 'far right', 'optimal distinctiveness', 'semi structured interviews', 'populism', 'identity']

# %%
print(list(set(clean_data.keywords[1])))
print(list(clean_data.cat_keywords[1]))
# Out:
# ['religious fundamentalism', 'religious violence', 'radicalization', 'extremism', 'suicide attacks']
# ['radicalism', 'fundamentalism']

# %% [markdown]
# ### 4. Nounbydoc
#
# Prepare data for van Lissa's code in R (negative binomial, topic modelling, cooccurrences)

# %%
nounbydoc = to_nounbydoc(clean_data)
nounbydoc
# Out:
#        doc_id                    term  freq
# 0       50129              radicalism     1
# 1       50129      significance quest     1
# 2       50129          goal shielding     1
# 3       50129           sacred values     1
# 4        2624              radicalism     1
# ...       ...                     ...   ...
# 13768   50382             personality     1
# 13769    2188             intolerance     1
# 13770    2188  pai teaching materials     1
# 13771    2188                  school     1
# 13772    2188             adolescence     1
#
# [13773 rows x 3 columns]

# %%
nounbydoc.to_csv(r"RTMR_Output/nounbydoc.csv", index = False)

# %% [markdown]
# ===========================================================================================================================
#
# ### Run R script for:
# * Negative Binomial (Pruning)
# * Word Frequency
# * Topic Modelling
# * Term co-occurrences
#
# ##### using van Lissa's R code
#
# ===========================================================================================================================

# %%
import subprocess

r_script_path = 'Keywords_RTMR_.R'
result = subprocess.run(['Rscript', r_script_path], capture_output=True, text=True)

if result.returncode == 0:
    print("R script ran successfully")
else:
    print("Error in running R script")
    print(result.stderr)
# Out:
# R script ran successfully

# %% [markdown]
# ## I. Word Frequency

# %%
freq_df = pd.read_csv(r"RTMR_Output/Keywords_freq.csv").sort_values(by= "Frequency", ascending=False).reset_index()
freq_df
# Out:
#     index         Word  Frequency
# 0      57   radicalism       2375
# 1      25    far right        567
# 2      35     islamist        369
# 3       6     conflict        257
# 4       1  adolescence        231
# ..    ...          ...        ...
# 71     48        peace         28
# 72     42     minority         28
# 73     21   employment         28
# 74     52      poverty         27
# 75     75   white race         27
#
# [76 rows x 3 columns]

# %%
plt_df = freq_df[freq_df.Word != "radicalism"].sort_values(by= "Frequency", ascending=True)
highlight_words = ['cognition', 'far right', "far left", "significance quest", "social exclusion", "adolescence", "social support", "deradicalization", "islamist", "identity"]
colors = ['turquoise' if word not in highlight_words else 'pink' for word in plt_df['Word']]

plt.figure(figsize=(10,14))
plt.barh(plt_df['Word'], plt_df['Frequency'], color=colors, height = 0.5)

plt.xlabel('Frequency', fontsize=12)  
plt.ylabel('Words', fontsize=12)
plt.title('Frequency of Words', fontsize=14)

plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=8)

# %% [markdown]
# ## II. Co-occurrences

# %%
cooc_df_incl = pd.read_csv(r"RTMR_Output/Keywords_cooc_inclrad.csv")
cooc_df_excl = pd.read_csv(r"RTMR_Output/Keywords_cooc_worad.csv")
cooc_df_excl
# Out:
#            term1        term2  cooc                     id
# 0       populism    far right   175      far rightpopulism
# 1      far right    elections   116     electionsfar right
# 2    immigration    far right   102   far rightimmigration
# 3    nationalism    far right    66   far rightnationalism
# 4       politics    far right    56      far rightpolitics
# ..           ...          ...   ...                    ...
# 78      violence  adolescence    15    adolescenceviolence
# 79  islamophobia    far right    15  far rightislamophobia
# 80      populism     ideology    15       ideologypopulism
# 81     prejudice  immigration    15   immigrationprejudice
# 82   religiosity     politics    15    politicsreligiosity
#
# [83 rows x 4 columns]

# %% [markdown]
# ### Network Visualisation

# %%
import networkx as nx

# %% [markdown]
# #### a) With "radicalism"

# %%
# Create the graph
G = nx.Graph()

# Add edges with the corresponding frequency as the weight
for index, row in cooc_df_incl.iterrows():
    G.add_edge(row['term1'], row['term2'], weight=row['cooc'])

# Draw the graph
plt.figure(figsize=(18, 12))

# Use spring layout for better visualization
pos = nx.spring_layout(G, seed=43, k=2, iterations=100)  # positions for all nodes

# Draw nodes with color
highlight_nodes = ['adolescence', "cognition", "significance quest", "social exclusion"]
colors = ['orange' if node not in highlight_nodes else 'darkviolet' for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_size=200, node_color=colors, alpha = 0.7)

# Draw edges with width and color proportional to the frequency
# Normalize frequencies to get a color gradient
weights = [G[u][v]['weight'] for u, v in G.edges]
min_weight = min(weights)
max_weight = max(weights)
normalized_weights = [(weight - min_weight) / (max_weight - min_weight) for weight in weights]

#mean_weight = np.mean(weights)
#std_weight = np.std(weights)
#normalized_weights = [(weight - mean_weight) / std_weight for weight in weights]



# Create a color map
cmap = plt.cm.Oranges

edges = nx.draw_networkx_edges(
    G, pos, 
    edge_color= weights, #normalized_weights, 
    width = 2, #width=[2 + 4*weight for weight in normalized_weights],  # adjust the width for better visualization
    edge_cmap=cmap
)

# Draw labels
nx.draw_networkx_labels(G, pos, font_size=9, font_family="sans-serif")

plt.title('Co-occurrence Network Including the Keyword "Radicalism"')
plt.colorbar(edges, label='Co-occurrence Frequency', shrink=0.5)
#plt.axis('off')  # Turn off the axis
plt.show()

# %% [markdown]
# #### Single pruning

# %%
cooc_df_s_prun = pd.read_csv(r"RTMR_Output/Keywords_cooc_single_prun.csv")

# %%
# Create the graph
G = nx.Graph()

# Add edges with the corresponding frequency as the weight
for index, row in cooc_df_s_prun.iterrows():
    G.add_edge(row['term1'], row['term2'], weight=row['cooc'])

# Draw the graph
plt.figure(figsize=(18, 14))

# Use spring layout for better visualization
pos = nx.spring_layout(G, seed=43, k=3, iterations=100)  # positions for all nodes

# Draw nodes with color
highlight_nodes = ['adolescence', "cognition", "significance quest", "social exclusion"]
colors = ['orange' if node not in highlight_nodes else 'darkviolet' for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_size=200, node_color=colors, alpha = 0.5)

# Draw edges with width and color proportional to the frequency
# Normalize frequencies to get a color gradient
weights = [G[u][v]['weight'] for u, v in G.edges]
min_weight = min(weights)
max_weight = max(weights)
normalized_weights = [(weight - min_weight) / (max_weight - min_weight) for weight in weights]

#mean_weight = np.mean(weights)
#std_weight = np.std(weights)
#normalized_weights = [(weight - mean_weight) / std_weight for weight in weights]



# Create a color map
cmap = plt.cm.Oranges

edges = nx.draw_networkx_edges(
    G, pos, 
    edge_color= weights, #normalized_weights, 
    width= 2, #[2 + 4*weight for weight in normalized_weights],  # adjust the width for better visualization
    edge_cmap=cmap
)

# Draw labels
nx.draw_networkx_labels(G, pos, font_size=9, font_family="sans-serif")

plt.title('Co-occurrence Network Single Pruning')
plt.colorbar(edges, label='Co-occurence Frequency', shrink=0.5)
#plt.axis('off')  # Turn off the axis
plt.show()

# %% [markdown]
# #### b) Without "radicalism"

# %%
# Create the graph
G = nx.Graph()

# Add edges with the corresponding frequency as the weight
for index, row in cooc_df_excl.iterrows():
    G.add_edge(row['term1'], row['term2'], weight=row['cooc'])

# Draw the graph
plt.figure(figsize=(18, 12))

# Use spring layout for better visualization
pos = nx.spring_layout(G, seed=43, k=2, iterations=100)  # positions for all nodes

# Draw nodes with color
highlight_nodes = ['adolescence'] + list(G.neighbors("adolescence"))
colors = ['orange' if node not in highlight_nodes else 'darkviolet' for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_size=200, node_color=colors, alpha = 0.5)

# Draw edges with width and color proportional to the frequency
# Normalize frequencies to get a color gradient
weights = [G[u][v]['weight'] for u, v in G.edges]
min_weight = min(weights)
max_weight = max(weights)
normalized_weights = [(weight - min_weight) / (max_weight - min_weight) for weight in weights]

#mean_weight = np.mean(weights)
#std_weight = np.std(weights)
#normalized_weights = [(weight - mean_weight) / std_weight for weight in weights]



# Create a color map
cmap = plt.cm.Oranges

edges = nx.draw_networkx_edges(
    G, pos, 
    edge_color= weights, #normalized_weights, 
    width= 2, #[2 + 4*weight for weight in normalized_weights],  # adjust the width for better visualization
    edge_cmap=cmap
)

# Draw labels
nx.draw_networkx_labels(G, pos, font_size=9, font_family="sans-serif")

plt.title('Co-occurrence Network Excluding the Keyword "Radicalism"')
plt.colorbar(edges, label='Co-occurrence Frequency', shrink=0.5)
#plt.axis('off')  # Turn off the axis
plt.show()

# %% [markdown]
# #### Single Pruning

# %%
cooc_df__excl_rad_s_prun = pd.read_csv(r"RTMR_Output/Keywords_cooc_wo_rad_single_prun.csv")

# %%
# Create the graph
G = nx.Graph()

# Add edges with the corresponding frequency as the weight
for index, row in cooc_df__excl_rad_s_prun.iterrows():
    G.add_edge(row['term1'], row['term2'], weight=row['cooc'])

# Draw the graph
plt.figure(figsize=(18, 14))

# Use spring layout for better visualization
pos = nx.spring_layout(G, seed=43, k=3, iterations=100)  # positions for all nodes

# Draw nodes with color
highlight_nodes = ['adolescence', "cognition", "significance quest", "social exclusion"]
colors = ['orange' if node not in highlight_nodes else 'darkviolet' for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_size=200, node_color=colors, alpha = 0.5)

# Draw edges with width and color proportional to the frequency
# Normalize frequencies to get a color gradient
weights = [G[u][v]['weight'] for u, v in G.edges]
min_weight = min(weights)
max_weight = max(weights)
normalized_weights = [(weight - min_weight) / (max_weight - min_weight) for weight in weights]

#mean_weight = np.mean(weights)
#std_weight = np.std(weights)
#normalized_weights = [(weight - mean_weight) / std_weight for weight in weights]



# Create a color map
cmap = plt.cm.Oranges

edges = nx.draw_networkx_edges(
    G, pos, 
    edge_color= weights, #normalized_weights, 
    width= 2, #[2 + 4*weight for weight in normalized_weights],  # adjust the width for better visualization
    edge_cmap=cmap
)

# Draw labels
nx.draw_networkx_labels(G, pos, font_size=9, font_family="sans-serif")

plt.title('Co-occurrence Network Excluding Radicalism and Single Pruning')
plt.colorbar(edges, label='Co-occurrence Frequency', shrink=0.5)
#plt.axis('off')  # Turn off the axis
plt.show()

# %% [markdown]
# #### c) Centred around "adolescence"

# %%
cooc_df_ado = pd.read_csv(r"RTMR_Output/Keywords_cooc_adolescence.csv")

# %%
# Create the graph
G = nx.Graph()

# Add edges with the corresponding frequency as the weight
for index, row in cooc_df_ado.iterrows():
    G.add_edge(row['term1'], row['term2'], weight=row['cooc'])

# Draw the graph
plt.figure(figsize=(14, 10))

# Use spring layout for better visualization
pos = nx.spring_layout(G, seed=43, k=2, iterations=100)  # positions for all nodes

# Draw nodes with color
highlight_nodes = ['adolescence']
colors = ['orange' if node not in highlight_nodes else 'red' for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_size=200, node_color=colors, alpha = 0.7)

# Draw edges with width and color proportional to the frequency
# Normalize frequencies to get a color gradient
weights = [G[u][v]['weight'] for u, v in G.edges]
min_weight = min(weights)
max_weight = max(weights)
normalized_weights = [(weight - min_weight) / (max_weight - min_weight) for weight in weights]

#mean_weight = np.mean(weights)
#std_weight = np.std(weights)
#normalized_weights = [(weight - mean_weight) / std_weight for weight in weights]



# Create a color map
cmap = plt.cm.Oranges

edges = nx.draw_networkx_edges(
    G, pos, 
    edge_color= weights, #normalized_weights, 
    width= 2, #[2 + 4*weight for weight in normalized_weights],  # adjust the width for better visualization
    edge_cmap=cmap
)

# Draw labels
nx.draw_networkx_labels(G, pos, font_size=9, font_family="sans-serif")

plt.title('Co-occurrence Network for Adolescence')
plt.colorbar(edges, label='Co-occurrence Frequency', shrink=0.5)
#plt.axis('off')  # Turn off the axis
plt.show()

# %% [markdown]
# ======================================================================
#
# Comparison between lemmatizations

# %%
import spacy
import nltk 
from nltk.stem import WordNetLemmatizer

# %%
# Define a text string 
text = "this is a sample text it contains some words that we can use for lemmatization" 


# Load the English language model in spaCy 
nlp = spacy.load("en_core_web_sm") 
doc = nlp(text)

# Lemmatize each token and print the result 
lem_spacy = []
for token in doc: 
  lem_spacy.append(token.lemma_)
print("spacy: ", " ".join(lem_spacy))


# Tokenize the text into individual words 
#tokens = nltk.word_tokenize(text) 
tokens = text.split(" ")

# Create a WordNetLemmatizer object 
lemmatizer = WordNetLemmatizer() 

# Lemmatize each word and print the result 
lem_nltk = []
for token in tokens: 
  lem_nltk.append(lemmatizer.lemmatize(token))
print("NLTK: ", " ".join(lem_nltk))
# Out:
# spacy:  this be a sample text it contain some word that we can use for lemmatization
# NLTK:  this is a sample text it contains some word that we can use for lemmatization

# %% [markdown]
# spacy it is
#
# ======================================================================
