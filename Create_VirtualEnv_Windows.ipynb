# %% [markdown]
# # Reproducible code
# For maximal reproducibility, we recommend to run the following code, which will be executed in the command prompt (Windows). You are then required to change the analyses notebook's kernel to "RadTMSR_env", which stores all required versions of the used modules.
#
# **Written in Python 4.20.11 and Jupyter Lab 4.0.7**
#
# More information on virtualenv, please visit https://docs.python.org/3/library/venv.html

# %%
# %%cmd
# pip install virtualenv
# Out:
# Microsoft Windows [Version 10.0.19045.4651]
# (c) Microsoft Corporation. Alle Rechte vorbehalten.
#
# C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR>pip install virtualenv
# Requirement already satisfied: virtualenv in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (20.25.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from virtualenv) (0.3.8)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from virtualenv) (3.13.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\nikit\appdata\local\programs\python\python310\lib\site-packages (from virtualenv) (3.11.0)
#
# C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR>

# %%
# %%cmd
# virtualenv RadTMSR_env
# Out:
# Microsoft Windows [Version 10.0.19045.4651]
# (c) Microsoft Corporation. Alle Rechte vorbehalten.
#
# C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR>virtualenv RadTMSR_env
# created virtual environment CPython3.10.11.final.0-64 in 3192ms
#   creator CPython3Windows(dest=C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR\RadTMSR_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=C:\Users\nikit\AppData\Local\pypa\virtualenv)
#     added seed packages: pip==24.1.2, setuptools==69.0.2, wheel==0.43.0
#   activators BashActivator,BatchActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
#
# C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR>

# %%
# %%cmd
# RadTMSR_env\Scripts\activate.bat
# which python
# pip install -r requirements.txt
#
# deactivate
# which python
# Out:
# Microsoft Windows [Version 10.0.19045.4651]
# (c) Microsoft Corporation. Alle Rechte vorbehalten.
#
# C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR>RadTMSR_env\Scripts\activate.bat
#
# (RadTMSR_env) C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR>which python
# /c/Users/nikit/Documents/Academia/B - Praktika und Research/Anusch phd/Textmining arniundbarni/RadTMSR/RadTMSR_env/Scripts/python
#
# (RadTMSR_env) C:\Users\nikit\Documents\Academia\B - Praktika und Research\Anusch phd\Textmining arniundbarni\RadTMSR>pip install -r requirements.txt
# Collecting en-core-web-sm==3.7.1 (from -r requirements.txt (line 7))
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 1.7 MB/s eta 0:00:00
# Collecting ipykernel==6.28.0 (from -r requirements.txt (line 1))
#   Using cached ipykernel-6.28.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting pandas==2.1.1 (from -r requirements.txt (line 2))
#   Using cached pandas-2.1.1-cp310-cp310-win_amd64.whl.metadata (18 kB)
# Collecting regex==2023.10.3 (from -r requirements.txt (line 3))
#   Using cached regex-2023.10.3-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting numpy==1.26.1 (from -r requirements.txt (line 4))
#   Using cached numpy-1.26.1-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting matplotlib==3.8.0 (from -r requirements.txt (line 5))
#   Using cached matplotlib-3.8.0-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting spacy==3.7.2 (from -r requirements.txt (line 6))
#   Using cached spacy-3.7.2-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Collecting stop-words==2018.7.23 (from -r requirements.txt (line 8))
#   Using cached stop_words-2018.7.23-py3-none-any.whl
# Collecting country-list==1.0.0 (from -r requirements.txt (line 9))
#   Using cached country_list-1.0.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting networkx==3.3 (from -r requirements.txt (line 10))
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting scipy==1.11.3 (from -r requirements.txt (line 11))
#   Using cached scipy-1.11.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting openpyxl==3.1.2 (from -r requirements.txt (line 12))
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting comm>=0.1.1 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached debugpy-1.8.2-cp310-cp310-win_amd64.whl.metadata (1.1 kB)
# Collecting ipython>=7.23.1 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached ipython-8.26.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting jupyter-client>=6.1.12 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached jupyter_client-8.6.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting nest-asyncio (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached psutil-6.0.0-cp37-abi3-win_amd64.whl.metadata (22 kB)
# Collecting pyzmq>=24 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached pyzmq-26.0.3-cp310-cp310-win_amd64.whl.metadata (6.1 kB)
# Collecting tornado>=6.1 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached tornado-6.4.1-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# Collecting traitlets>=5.4.0 (from ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting python-dateutil>=2.8.2 (from pandas==2.1.1->-r requirements.txt (line 2))
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.1.1->-r requirements.txt (line 2))
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas==2.1.1->-r requirements.txt (line 2))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.8.0->-r requirements.txt (line 5))
#   Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib==3.8.0->-r requirements.txt (line 5))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.8.0->-r requirements.txt (line 5))
#   Using cached fonttools-4.53.1-cp310-cp310-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.8.0->-r requirements.txt (line 5))
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting pillow>=6.2.0 (from matplotlib==3.8.0->-r requirements.txt (line 5))
#   Using cached pillow-10.4.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.8.0->-r requirements.txt (line 5))
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached murmurhash-1.0.10-cp310-cp310-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached cymem-2.0.8-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached preshed-3.0.9-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached thinc-8.2.5-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached srsly-2.4.8-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting jinja2 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in c:\users\nikit\documents\academia\b - praktika und research\anusch phd\textmining arniundbarni\radtmsr\radtmsr_env\lib\site-packages (from spacy==3.7.2->-r requirements.txt (line 6)) (69.0.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Collecting et-xmlfile (from openpyxl==3.1.2->-r requirements.txt (line 12))
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached prompt_toolkit-3.0.47-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack-data (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting exceptiongroup (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.6 (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting colorama (from ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached platformdirs-4.2.2-py3-none-any.whl.metadata (11 kB)
# Collecting pywin32>=300 (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached pywin32-306-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached pydantic_core-2.20.1-cp310-none-win_amd64.whl.metadata (6.7 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.1.1->-r requirements.txt (line 2))
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached blis-0.7.11-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting click<9.0.0,>=7.1.1 (from typer<0.10.0,>=0.3.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting parso<0.9.0,>=0.8.3 (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.7.2->-r requirements.txt (line 6))
#   Using cached marisa_trie-1.2.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting wcwidth (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Using cached asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=7.23.1->ipykernel==6.28.0->-r requirements.txt (line 1))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached ipykernel-6.28.0-py3-none-any.whl (114 kB)
# Using cached pandas-2.1.1-cp310-cp310-win_amd64.whl (10.7 MB)
# Using cached regex-2023.10.3-cp310-cp310-win_amd64.whl (269 kB)
# Using cached numpy-1.26.1-cp310-cp310-win_amd64.whl (15.8 MB)
# Using cached matplotlib-3.8.0-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached spacy-3.7.2-cp310-cp310-win_amd64.whl (12.1 MB)
# Using cached country_list-1.0.0-py3-none-any.whl (1.5 MB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached scipy-1.11.3-cp310-cp310-win_amd64.whl (44.1 MB)
# Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached cymem-2.0.8-cp310-cp310-win_amd64.whl (39 kB)
# Using cached debugpy-1.8.2-cp310-cp310-win_amd64.whl (4.8 MB)
# Using cached fonttools-4.53.1-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached ipython-8.26.0-py3-none-any.whl (817 kB)
# Using cached jupyter_client-8.6.2-py3-none-any.whl (105 kB)
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Using cached langcodes-3.4.0-py3-none-any.whl (182 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached murmurhash-1.0.10-cp310-cp310-win_amd64.whl (25 kB)
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Using cached pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Using cached preshed-3.0.9-cp310-cp310-win_amd64.whl (122 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp310-none-win_amd64.whl (1.9 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached pyzmq-26.0.3-cp310-cp310-win_amd64.whl (773 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.4.8-cp310-cp310-win_amd64.whl (481 kB)
# Using cached thinc-8.2.5-cp310-cp310-win_amd64.whl (1.5 MB)
# Using cached tornado-6.4.1-cp38-abi3-win_amd64.whl (438 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached typer-0.9.4-py3-none-any.whl (45 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.3.4-py3-none-any.whl (50 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached psutil-6.0.0-cp37-abi3-win_amd64.whl (257 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached blis-0.7.11-cp310-cp310-win_amd64.whl (6.6 MB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Using cached language_data-1.2.0-py3-none-any.whl (5.4 MB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Using cached platformdirs-4.2.2-py3-none-any.whl (18 kB)
# Using cached prompt_toolkit-3.0.47-py3-none-any.whl (386 kB)
# Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Using cached pywin32-306-cp310-cp310-win_amd64.whl (9.2 MB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Using cached executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Using cached marisa_trie-1.2.0-cp310-cp310-win_amd64.whl (152 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, stop-words, pywin32, pytz, pure-eval, cymem, country-list, urllib3, tzdata, typing-extensions, traitlets, tornado, spacy-loggers, spacy-legacy, smart-open, six, regex, pyzmq, pyparsing, pygments, psutil, prompt-toolkit, platformdirs, pillow, parso, packaging, numpy, networkx, nest-asyncio, murmurhash, MarkupSafe, marisa-trie, kiwisolver, idna, fonttools, executing, exceptiongroup, et-xmlfile, decorator, debugpy, cycler, colorama, charset-normalizer, certifi, catalogue, annotated-types, wasabi, tqdm, srsly, scipy, requests, python-dateutil, pydantic-core, preshed, openpyxl, matplotlib-inline, language-data, jupyter-core, jinja2, jedi, contourpy, comm, cloudpathlib, click, blis, asttokens, typer, stack-data, pydantic, pandas, matplotlib, langcodes, jupyter-client, ipython, confection, weasel, thinc, ipykernel, spacy, en-core-web-sm

# %%
# %%cmd
# RadTMSR_env\Scripts\python -m ipykernel install --name "RadTMSR_env"
