# %%
# !pip freeze
# Out:
# absl-py==2.1.0
# aiofiles==0.8.0
# aiohttp==3.9.1
# aiosignal==1.3.1
# aiosqlite==0.17.0
# alabaster==0.7.16
# annotated-types==0.6.0
# anyascii==0.3.2
# anyio==4.0.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# arviz==0.18.0
# astropy==5.3.4
# asttokens==2.4.0
# astunparse==1.6.3
# async-lru==2.0.4
# async-timeout==4.0.3
# asyncpraw==7.7.1
# asyncprawcore==2.4.0
# attrs==23.1.0
# autograd==1.6.2
# Babel==2.13.1
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==6.1.0
# blis==0.7.11
# cachetools==5.3.3
# catalogue==2.0.10
# certifi==2023.7.22
# cffi==1.16.0
# cfgv==3.4.0
# charset-normalizer==3.3.1
# click==8.1.7
# cloudpathlib==0.16.0
# cloudpickle==3.0.0
# colorama==0.4.6
# comm==0.1.4
# confection==0.1.4
# cons==0.4.6
# contourpy==1.1.1
# contractions==0.1.73
# country-list==1.0.0
# crccheck==1.3.0
# cvxopt==1.3.2
# cycler==0.12.1
# cymem==2.0.8
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.8
# dm-tree==0.1.8
# docutils==0.20.1
# ...
